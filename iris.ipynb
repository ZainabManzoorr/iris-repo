# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()

# %%
df = pd.read_excel('iris_dataset.xlsx')

# %%
df.keys()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.describe().head()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
target = df["class"]
print(target)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, Length: 150, dtype: object

# %% [markdown]
# #What is the problem?
# we are trying to use the attributes of flowers to predict the sepcie of flower. Specifically, we are using sepal length and width and petal length and width if an iris is of type setosa , virginicia or versicolor.
#
# this is multiclass classification problem.
#
# Create pandas dataframe from data
# We could do our full anlysis using numpy and numpy arrays but we will create pandas dataframe because it makes some things simpler and also to get some practice on pandas.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
col = "sepal_length"
df[col].hist()
plt.suptitle(col)
plt.show()

# %%
col = "sepal_width"
df[col].hist()
plt.suptitle(col)
plt.show()

# %%
col = "petal_length"
df[col].hist()
plt.suptitle(col)
plt.show()

# %%
col = "sepal_width"
df[col].hist()
plt.suptitle(col)
plt.show()

# %%
col = "sepal_length"
sns.relplot( x=col , y="class" ,hue="class", data=df)
plt.suptitle(col, y=1.03)
# Out:
# Text(0.5, 1.03, 'sepal_length')

# %%
col = "sepal_width"
sns.relplot( x=col , y="class" ,hue="class", data=df)
plt.suptitle(col, y=1.03)
# Out:
# Text(0.5, 1.03, 'sepal_width')

# %%
col = "petal_length"
sns.relplot( x=col , y="class" ,hue="class", data=df)
plt.suptitle(col, y=1.03)
# Out:
# Text(0.5, 1.03, 'petal_length')

# %%
col = "petal_width"
sns.relplot( x=col , y="class" ,hue="class", data=df)
plt.suptitle(col, y=1.03)
# Out:
# Text(0.5, 1.03, 'petal_width')

# %%
sns.pairplot(df , hue="class")

# %%
from sklearn.model_selection import train_test_split

# %%
df_train ,df_test =  train_test_split(df, test_size=0.25)

# %%
df_train.shape
# Out:
# (112, 5)

# %%
df_test.shape
# Out:
# (38, 5)

# %%
df_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 11            4.8          3.4           1.6          0.2      Iris-setosa
# 29            4.7          3.2           1.6          0.2      Iris-setosa
# 13            4.3          3.0           1.1          0.1      Iris-setosa
# 115           6.4          3.2           5.3          2.3   Iris-virginica
# 91            6.1          3.0           4.6          1.4  Iris-versicolor

# %%
x_train = df_train.drop(columns=['class']).values
x_train
# Out:
# array([[4.8, 3.4, 1.6, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.3, 3. , 1.1, 0.1],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.1, 3. , 4.6, 1.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [6.1, 3. , 4.9, 1.8],
#        [7.7, 2.8, 6.7, 2. ],
#        [4.8, 3.4, 1.9, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [5.9, 3. , 5.1, 1.8],
#        [7.4, 2.8, 6.1, 1.9],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.5, 3.2, 5.1, 2. ],
#        [5.5, 2.4, 3.7, 1. ],
#        [6.7, 2.5, 5.8, 1.8],
#        [5.2, 4.1, 1.5, 0.1],
#        [6.1, 2.8, 4. , 1.3],
#        [6.9, 3.1, 5.4, 2.1],
#        [4.4, 3. , 1.3, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [7.2, 3.6, 6.1, 2.5],
#        [6. , 2.7, 5.1, 1.6],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.7, 3.3, 5.7, 2.1],
#        [5. , 3.2, 1.2, 0.2],
#        [6.6, 3. , 4.4, 1.4],
#        [6.9, 3.2, 5.7, 2.3],
#        [4.9, 2.4, 3.3, 1. ],
#        [4.6, 3.1, 1.5, 0.2],
#        [6.2, 3.4, 5.4, 2.3],
#        [6. , 2.9, 4.5, 1.5],
# ...

# %%
x_train.shape
# Out:
# (112, 4)

# %%
y_train = df_train['class'].values
y_test = df_test['class'].values

# %%
data['class']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, Length: 150, dtype: object

# %%
x_test = df_test.drop(columns=['class']).values

# %%
# Standardize the features (optional but recommended)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Initialize and train the Logistic Regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Predict on the test set
y_pred = model.predict(x_test)

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy:.2f}')
print('Confusion Matrix:\n', conf_matrix)
print('Classification Report:\n', report)
# Out:
# Accuracy: 0.92
# Confusion Matrix:
#  [[11  0  0]
#  [ 0 11  0]
#  [ 0  3 13]]
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.79      1.00      0.88        11
#  Iris-virginica       1.00      0.81      0.90        16
#
#        accuracy                           0.92        38
#       macro avg       0.93      0.94      0.93        38
#    weighted avg       0.94      0.92      0.92        38

# %%
# Get the coefficients (log-odds)
coefficients = pd.DataFrame({'Feature': df_train.drop(columns=['class']).columns, 'Coefficient': model.coef_[0]})

# %%
# Sort by absolute value for magnitude of impact
coefficients = coefficients.reindex(coefficients['Coefficient'].abs().sort_values(ascending=False).index)

# %%
# Visualize feature importance
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=coefficients, x='Coefficient', y='Feature', palette='viridis')
plt.title('Feature Importance (Absolute Coefficients - Log-Odds)')
plt.xlabel('Coefficient Value (Log-Odds)')
plt.ylabel('Feature')
plt.grid(axis='x', alpha=0.75)
plt.show()
# Out:
# C:\Users\ENVY\AppData\Local\Temp\ipykernel_21536\1618480919.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=coefficients, x='Coefficient', y='Feature', palette='viridis')
